# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Creating a variable that contains the path of the file I will use
student_filepath = "/workspaces/Student-Performance-Dataset/student_performance_data.csv"

# Reading the file into a variable student_data
student_data = pd.read_csv(student_filepath, index_col="StudentID")

# %%
student_data
# Out:
#            Gender  Age  StudyHoursPerWeek  AttendanceRate   GPA        Major  \
# StudentID
# 1            Male   24                 37           90.75  3.47         Arts
# 2          Female   22                 37           74.90  2.32    Education
# 3            Male   22                 10           53.36  2.38     Business
# 4            Male   24                 10           70.26  3.46      Science
# 5            Male   18                 19           74.87  2.31    Education
# ...           ...  ...                ...             ...   ...          ...
# 496          Male   22                 37           76.61  2.97      Science
# 497          Male   23                 11           56.29  3.20      Science
# 498        Female   20                  6           56.64  3.20      Science
# 499          Male   22                 18           57.18  2.05     Business
# 500        Female   24                 21           96.99  2.64  Engineering
#
# ...

# %%
student_data.describe().T
# Out:
#                    count      mean        std    min      25%    50%    75%  \
# Age                500.0  20.95600   2.000517  18.00  19.0000  21.00  23.00
# StudyHoursPerWeek  500.0  19.87600  11.471347   1.00  10.0000  20.50  30.00
# AttendanceRate     500.0  74.99038  14.565917  50.01  62.6075  75.73  87.22
# GPA                500.0   2.98516   0.563620   2.00   2.4875   3.00   3.48
#
#                      max
# Age                24.00
# StudyHoursPerWeek  39.00
# AttendanceRate     99.97
# GPA                 3.99

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 1 to 500
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Gender                     500 non-null    object
#  1   Age                        500 non-null    int64
#  2   StudyHoursPerWeek          500 non-null    int64
#  3   AttendanceRate             500 non-null    float64
#  4   GPA                        500 non-null    float64
#  5   Major                      500 non-null    object
#  6   PartTimeJob                500 non-null    object
#  7   ExtraCurricularActivities  500 non-null    object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 35.2+ KB

# %%
sns.pairplot(student_data)

# %% [markdown]
# Mapa de calor para expresar la correlación entre las diferentes variables.

# %%
student_data.head()
# Out:
#            Gender  Age  StudyHoursPerWeek  AttendanceRate   GPA      Major  \
# StudentID
# 1            Male   24                 37           90.75  3.47       Arts
# 2          Female   22                 37           74.90  2.32  Education
# 3            Male   22                 10           53.36  2.38   Business
# 4            Male   24                 10           70.26  3.46    Science
# 5            Male   18                 19           74.87  2.31  Education
#
#           PartTimeJob ExtraCurricularActivities
# StudentID
# 1                 Yes                        No
# 2                  No                        No
# 3                  No                        No
# 4                 Yes                        No
# 5                 Yes                        No

# %%
# Setting the size of the figure
plt.figure(figsize=(10, 8))

# Heatmap showing the relationship between the variables of the dataframe
numerical_variables_df = student_data[['StudyHoursPerWeek', 'GPA', 'AttendanceRate']]
sns.heatmap(data=numerical_variables_df, annot=True, fmt='.2f', linewidths=0.5)


# Adding a title to the heatmap
plt.title("Relationship between the variables")
# Out:
# Text(0.5, 1.0, 'Relationship between the variables')

# %% [markdown]
# Exploración de cómo se distribuyen las diferentes variables.

# %% [markdown]
# ¿Cómo se distribuyen las notas (GPA)?

# %%
plt.figure(figsize=(10,6))

sns.histplot(data=student_data, kde=True, x='GPA')
# Out:
# <Axes: xlabel='GPA', ylabel='Count'>

# %% [markdown]
# ## Distribución de notas por major.

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=student_data, x='GPA', hue='Major', shade=True)
# Out:
# /tmp/ipykernel_2314/4028184499.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=student_data, x='GPA', hue='Major', shade=True)
# /opt/conda/envs/myenv/lib/python3.11/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/envs/myenv/lib/python3.11/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# Distribución del género.

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=student_data, x='Gender')
#plt.figure(figsize=(10,6))
#sns.barplot(student_data['Gender'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# Distribución de las edades por género.

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=student_data, x='Age', hue='Gender', kde=True, multiple='stack')
# Out:
# /opt/conda/envs/myenv/lib/python3.11/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/envs/myenv/lib/python3.11/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/envs/myenv/lib/python3.11/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=student_data, y='Major')
# Out:
# <Axes: xlabel='count', ylabel='Major'>

# %% [markdown]
# ¿Cómo se distribuye el AttendanceRate?

# %%
plt.figure(figsize=(10,6))

sns.histplot(data=student_data, kde=True, x='AttendanceRate')
# Out:
# <Axes: xlabel='AttendanceRate', ylabel='Count'>

# %% [markdown]
# Distribución de las horas de estudio.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=student_data, x='StudyHoursPerWeek')
# Out:
# <Axes: xlabel='StudyHoursPerWeek', ylabel='Count'>

# %% [markdown]
# ## Analizando las relaciones entre las variables

# %% [markdown]
# ¿Cuál es la relación entre GPA y AttendanceRate?

# %%
plt.figure(figsize=(10,6))

sns.regplot(data=student_data, x='AttendanceRate', y='GPA')
# Out:
# <Axes: xlabel='AttendanceRate', ylabel='GPA'>

# %% [markdown]
# Relación entre género y notas.

# %%
plt.figure(figsize=(10,6))

sns.barplot(data=student_data, x='Gender', y='GPA', palette='coolwarm', hue='Gender', ci=None)
# Out:
# /tmp/ipykernel_2314/641771996.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=student_data, x='Gender', y='GPA', palette='coolwarm', hue='Gender', ci=None)
# /opt/conda/envs/myenv/lib/python3.11/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/envs/myenv/lib/python3.11/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Gender', ylabel='GPA'>

# %% [markdown]
# Relación entre las horas de estudio y el GPA.

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=student_data, x='StudyHoursPerWeek', y='GPA')
# Out:
# <Axes: xlabel='StudyHoursPerWeek', ylabel='GPA'>

# %% [markdown]
# ¿Hay una relación entre la edad y las notas?

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=student_data, x='Age', y='GPA')
# Out:
# <Axes: xlabel='Age', ylabel='GPA'>

# %% [markdown]
# ## Categorías y comparación de datos

# %% [markdown]
# ¿Cuál es la media de notas(GPA) por cada especialidad?

# %%
avg_gpa_by_major = student_data.groupby(by='Major').GPA.mean().to_frame().sort_values(by='GPA')
plt.figure(figsize=(10,6))

sns.barplot(data=avg_gpa_by_major, x='Major', y='GPA')
# Out:
# <Axes: xlabel='Major', ylabel='GPA'>

# %%
print(avg_gpa_by_major)
# Out:
#                   GPA
# Major
# Education    2.938866
# Science      2.958250
# Engineering  2.972844
# Arts         3.007100
# Business     3.035965

# %% [markdown]
# ¿Quién dedica más tiempo a estudiar? ¿Chicos o chicas?

# %%
# Checking the mean of both male and female attendance
mean_study_hours_by_gender = student_data.groupby('Gender')['StudyHoursPerWeek'].mean()
print(mean_study_hours_by_gender)
# Out:
# Gender
# Female    20.023438
# Male      19.721311
# Name: StudyHoursPerWeek, dtype: float64

# %%
sns.barplot(data=student_data, x='Gender', y='StudyHoursPerWeek')
# Out:
# <Axes: xlabel='Gender', ylabel='StudyHoursPerWeek'>

# %% [markdown]
# ¿Cuál es la relación entre attendancerate y parttimejob?

# %%
attendance_by_job = student_data.groupby('PartTimeJob')['AttendanceRate'].mean()
print(attendance_by_job)
# Out:
# PartTimeJob
# No     75.400690
# Yes    74.635187
# Name: AttendanceRate, dtype: float64

# %%
sns.boxplot(x='PartTimeJob', y='AttendanceRate', data=student_data)
plt.title('Tasa de asistencia según tener un trabajo a tiempo parcial')
plt.show()
# Out:
# /opt/conda/envs/myenv/lib/python3.11/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# ¿Afectan el tener un partime job a las notas?

# %%
gpa_by_job = student_data.groupby('PartTimeJob')['GPA'].mean()
print(gpa_by_job)
# Out:
# PartTimeJob
# No     2.960690
# Yes    3.006343
# Name: GPA, dtype: float64

# %%
sns.boxplot(x='PartTimeJob', y='GPA', data=student_data)
plt.title('GPA según tener un trabajo a tiempo parcial')
plt.show()
# Out:
# /opt/conda/envs/myenv/lib/python3.11/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
